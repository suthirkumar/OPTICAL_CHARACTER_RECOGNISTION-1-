# %% [markdown]
# <a href="https://colab.research.google.com/github/suthirkumar/OPTICAL_CHARACTER_RECOGNISTION-1-/blob/main/ocr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt install tesseract-ocr
# !pip install pytesseract Pillow
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 34 not upgraded.
# ...

# %%
import pytesseract
from PIL import Image
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8be0bde8-bbdf-4360-8ecd-7e0b1a3905e3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8be0bde8-bbdf-4360-8ecd-7e0b1a3905e3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
image_path = list(uploaded.keys())[0]
img = Image.open(image_path)

# Display the image
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
# Extract text
text = pytesseract.image_to_string(img)
print("🔍 Extracted Text:")
print(text)
# Out:
# 🔍 Extracted Text:
# ve
#
# y KPR Institute of
# WN Le) Engineering and
# Technology
#
# Madras Section IEEE POWER
# (Autonomous, NAAC“A") ELECTRONICS SOCIETY
#
#
#
# IEEE KPRIET Power ees Society ve
#
# iy
# by
# = ‘CELESTIA‘25—
#
#
#
#
#
# eee E Zz Bs - REGISTRATION FEE
# pe er senNesaeoen . = 150/Head - Non IEEE Member
# Circuit Debugging pst win Phin eet
#
# Be ee = 100/Head - IEEE Member
# Auction Mania
#
# 8] 08.05.2025 ©) 9:30 A.M. - 4:00 P.M.
#
# Food and Refreshments
# will be provided
#
#
#
# Register now
#
# Advisors
#
# Dr.K.Porkumaran ,Chairman,IEEE,Madras Section
#
# Dr.S.Albert Alexander,Chairman, IEEE PELS, Madras Section Student coordinators
#
# Dr.K.Mohana Sundaram , Vice Chairman,IEEE PELS, Madras Section Mr.Karthikeyan M - Ill EEE
#
# Mrs.B.Lalitha , AP Il / EEE, IEEE KPRIET PELS (95972 11792)
# Mr.Jeffery Vibin J - Ill EEE
#
# Counsellor - IEEE KPRIET SB (93613 87774)
#
# Dr. Dinesh Chellapan, SMIEEE
#
# ...

# %%
import cv2
import numpy as np

# Convert to grayscale and threshold
img_cv = cv2.imread(image_path)
gray = cv2.cvtColor(img_cv, cv2.COLOR_BGR2GRAY)
_, thresh = cv2.threshold(gray, 150, 255, cv2.THRESH_BINARY)

# Convert back to PIL Image
processed_img = Image.fromarray(thresh)

# OCR on preprocessed image
text_processed = pytesseract.image_to_string(processed_img)
print("📃 Text after preprocessing:")
print(text_processed)
# Out:
# 📃 Text after preprocessing:
# PE
#
# 2 KPR Institute of
# ey ABP F=ngineering and
# Technology Madras Section
#
# Learr Boyene — ¢Autonemous. NAC "A"
#
# IEEE POWER
# ELECTRONICS SOCIETY
#
# / IEEE KPRIET Power Electronics one SBC
# Organizes \ /
#
# - CELESTIA25.
#
# Paper Presentation
# Circuit Debugging
# Auction Mania
#
#
#
# REGISTRATION FEE
# = 150/Head - Non IEEE Member
# = 100/Head - IEEE Member
#
#
#
#
#
# Sean 1 ohana a
#
# era
#
#
#
# Food and Refreshments
# will be provided
# Register now
#
# Advisors
# Dr.K.Porkumaran ,Chairman,lIEEE,Madras Section
#
# Or.S.Albert Alexander,Chairman,IEEE PELS, Madras Section Student coordinators
#
# Or.K.Mohana Sundaram , Vice Chairman,JEEE PELS, Madras Section Mr.Karthikeyan M - Ill EEE
#
# Mrs.B.Lalitha , AP Il / EEE, IEEE KPRIET PELS (95972 11792 )
# Mr.Jeffery Vibin J - ill EEE
#
# Counsellor - IEEE KPRIET SB (93613 87774 )
#
# Dr. Dinesh Chellapan, SMIEEE
#
# uF
# s"s
# g
#
# a
#
#
#
# ...
